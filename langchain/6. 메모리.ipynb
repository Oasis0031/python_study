# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])

from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate
# Out:
# sk-proj-7I-_iCgmJM-p

# %%
chat = ChatOpenAI(temperature=0)

# %%
chat.invoke("방금 내가 물어본 질문을 다시 전달해줘")
# Out:
# AIMessage(content='물어본 질문을 다시 한 번 말해주시겠어요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 31, 'total_tokens': 55, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfItaYFTs3fx2LOTpEjTLVZwFQAXs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24f4-599b-7cc0-a172-91a650d245c1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 24, 'total_tokens': 55, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## ConversationBufferMemory

# %%
from langchain_classic.memory import ConversationBufferMemory

# %%
memory = ConversationBufferMemory()

# %%
memory.save_context(
    {"input":"Hi"},
    {"output":"How are you"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': 'Human: Hi\nAI: How are you'}

# %% [markdown]
# ## return_message=True
# - history 객체에 AIMessage, HumanMessage로 저장하게 만든다.

# %%
memory = ConversationBufferMemory(return_messages=True)

# %%
memory.save_context(
    {"input":"Hi"},
    {"output":"How are you"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs=
# ...

# %% [markdown]
# ## 문제점

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
chat.invoke("제 이름은 엠폴리오에요.")
# Out:
# AIMessage(content='안녕하세요, 엠폴리오님. 만나서 반가워요. 저는 여러분의 개인 비서 AI입니다. 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 19, 'total_tokens': 73, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJUYIHUSAk5aK1xj5p54VGzv87xm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2517-5030-74f0-80da-97057dc19719-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 54, 'total_tokens': 73, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## 체인

# %%
from langchain_classic.chains import ConstitutionalChain

# %%
llm = ChatOpenAI(temperature=0.1)
memory = ConversationBufferMemory(return_messages=True)

chain = ConversationChain(llm=llm, memory=memory)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 4
#       1 llm = ChatOpenAI(temperature=0.1)
#       2 memory = ConversationBufferMemory(return_messages=True)
#       3
# ----> 4 chain = ConversationChain(llm=llm, memory=memory)
#
# NameError: name 'ConversationChain' is not defined

# %%
final_chain = chain |

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[142], line 2
#       1 import langchain
# ----> 2 from langchain.chains import ConversationChain
#       3 from langchain_openai import ChatOpenAI
#       4 from langchain.memory import ConversationBufferMemory
#       5
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %% [markdown]
# ## ConversationBufferWindowMemory

# %%
from langchain_classic.memory import ConversationBufferWindowMemory
from langchain_classic.chains import ConversationChain

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

# %%
memory.save_context({"input": "1"}, {"output": "1"})
memory.save_context({"input": "2"}, {"output": "2"})
memory.save_context({"input": "3"}, {"output": "3"})
memory.save_context({"input": "4"}, {"output": "4"})
memory.save_context({"input": "5"}, {"output": "5"})
memory.save_context({"input": "6"}, {"output": "6"})

# %%
print_memory()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 print_memory()
#
# TypeError: print_memory() missing 1 required positional argument: 'memory'

# %%
def print_memory(memory):
    # load_memory_variables({})를 통해 저장된 대화 내역을 가져옵니다.
    history = memory.load_memory_variables({})

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

chain = ConversationChain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 3
#       1 memory = ConversationBufferWindowMemory(return_messages=True, k=4)
#       2
# ----> 3 chain = Conver
#
# NameError: name 'Conver' is not defined

# %%
from langchain_community.chains import ConversationChain
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 from langchain_community.chains import ConversationChain
#
# ImportError: cannot import name 'ConversationChain' from 'langchain_community.chains' (C:\back_0900_ksj\python\workspace\venv\Lib\site-packages\langchain_community\chains\__init__.py)

# %% [markdown]
# ## ConversationSummaryMemory

# %%
from langchain_classic.memory import ConversationSummaryMemory

# %%
llm = ChatOpenAI(temperature=0.1)
memory = ConversationSummaryMemory(return_messages=True, llm=llm)

# %%
chain = ConversationChain(memory=memory, llm=llm)
# Out:
# C:\Users\oasis\AppData\Local\Temp\ipykernel_29304\2606382161.py:1: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use `langchain_core.runnables.history.RunnableWithMessageHistory` instead.
#   chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("")

# %% [markdown]
# # ConversationSummaryBufferMemory
#  - 요약본의 토큰 수를 제한하는 메모리

# %%
from langchain_classic.memory import ConversationSummaryBufferMemory

# %%
llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryBufferMemory(
    llm=llm,
    return_message=True,
    max_token_limit=50
)

# %%
chain  = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("rtx5080을 공짜로 얻는 방법에 대해 알려줘.")
chain.invoke("미국을 공짜로 얻는 방법에 대해 알려줘.")
chain.invoke("삼성 갤럭시 S27 울트라를 공짜로 얻는 방법에 대해 알려줘.")

chain.invoke("내가 공짜로 얻고싶은 것은 뭐니")
# Out:
# {'input': '내가 공짜로 얻고싶은 것은 뭐니',
#  'history': 'System: 사람이 AI에게 rtx5080을 공짜로 얻는 방법에 대해 물어봅니다. AI는 그 정보를 알 수 없지만 일반적으로 그래픽 카드를 무료로 얻는 방법은 거의 없다고 답변합니다. 미국을 공짜로 얻는 방법은 없다고 답변하며, 여행을 계획할 때 할인 혜택을 활용하거나 저렴한 항공권을 찾는 등의 방법으로 비용을 절감할 수 있다고 설명합니다. 삼성 갤럭시 S27 울트라를 공짜로 얻는 방법에 대해 알려줄 수 없다고 하며, 스마트폰을 무료로 얻는 방법은 거의 없지만 휴대폰 업체의 프로모션 이벤트나 특별 혜택을 활용하거나 중고나 중고품을 구매하는 등의 방법으로 저렴하게 구매할 수 있다고 안내합니다. 다른 질문이 있으면 도와줄 수 있다고 말합니다.',
#  'response': '공짜로 얻고 싶은 것이 무엇인지 알려주시면 해당 제품이나 서비스에 대해 정보를 제공해드릴 수 있습니다. 혹시 특정 제품이나 서비스에 대해 궁금한 점이 있으신가요?'}

# %%
print_memory()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 print_memory()
#
# TypeError: print_memory() missing 1 required positional argument: 'memory'

# %% [markdown]
# ## ConversationKGMemory

# %%
from langchain_community.memory.kg import ConversationKGMemory

# %%
memory = ConversationKGMemory(llm=llm, return_messages=True)

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("나는 어제 올림푸스산에 갔어. 제우스 신전이 거기에 있었어.")
chain.invoke("올림푸스산에서 아테나는 화를 냈고, 포세이돈은 아테나를 진정시켰어.")

chain.invoke("올림푸스산에서 화를 낸 사람은?")
# Out:
# {'input': '올림푸스산에서 화를 낸 사람은?',
#  'history': [SystemMessage(content='On 올림푸스산: 올림푸스산 있었어 제우스 신전. 올림푸스산 화를 낸 사람은 제우스 신.', additional_kwargs={}, response_metadata={})],
#  'response': '올림푸스산에서 화를 낸 사람은 제우스 신입니다. 이곳에는 제우스 신전이 있었어요. 그래서 올림푸스산은 그리스 신화에서 중요한 장소 중 하나로 여겨집니다.'}

# %%
memory.load_memory_variables({"input": "올림푸스산에서 아테나는 화를 냈고, 포세이돈은 아테나를 진정시켰어"})
# Out:
# {'history': [SystemMessage(content='On 올림푸스산: 올림푸스산 있었어 제우스 신전. 올림푸스산 화를 낸 사람은 제우스 신.', additional_kwargs={}, response_metadata={})]}

# %%
chain.invoke("My hobby is baseball,soccer,basketball.")
chain.invoke("My favorite food is chicken, stake and pizza.")

chain.invoke("What is my favorite food?")
# Out:
# {'input': 'What is my favorite food?',
#  'history': [],
#  'response': "I'm sorry, I do not have access to that information. Can you tell me what your favorite food is?"}

# %% [markdown]
# ## LCEL 방법 권장

# %%
# MessagesPlaceholder: 프롬프트 안에 “대화 기록”을 끼워 넣는 자리표시 역할
# InMemoryChatMessageHistory: 대화 내용을 메모리에 저장
# RunnableWithMessageHistory: 체인 + 메모리 + 프롬프트를 자동으로 연결해주는 랩퍼
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """
        인간을 도와주는 AI 도구입니다. 친절하게 답변하세요.
    """),
    # 저장소 메모리 위치
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}"),
])

# %%
chain = prompt | chat

# %% [markdown]
# ### 저장소(메모리) 생성

# %%
# redis, db
store ={}

def get_history(session_id):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_message_key="question",
    history_message_key="chat_history"
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "내 이름은 세종이야."
    },
    config={"configurable": {"session_id": "user1"}} 
)

# %%
print(result.content)
# Out:
# 안녕하세요, 세종님! 만나서 반가워요. 무엇을 도와드릴까요?

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history"
).with_config(
    cofigurable={"session_id": "user2"}
)

# %%
result = chain_with_memory.invoke({
        "question": "내 이름은 세종이야."
    },
    config={"configurable": {"session_id": "user1"}} 
                                 )

# %%
print(result.content)
# Out:
# 안녕하세요, 세종님! 만나서 반가워요. 무엇을 도와드릴까요?

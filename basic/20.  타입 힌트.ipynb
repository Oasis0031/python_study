# %%
#클래스 또는 메서드에서 사용이 가능(v3.11)

class User:
    name =""
    age = 0
    address = ""
    phone = ""

# %%
class User:

    def __init__(self, name="", age=0, address="", phone=""):
        self.name = name
        self.age = age
        self.address = address
        self.phone = phone

# %%
class User:
    name: str
    age: int
    address: str
    phone: str

    def __init__(self, name, age, address, phone):
        self.name = name
        self.age = age
        self.address = address
        self.phone = phone

    def print_hobby(self, hobby) -> None:
        print(f"{self.name}의 취미는 {hobby}입니다.")

# %%
han = User("한보고", 30, "서울시 종로구", "010-4567-7894")

han.name
# Out:
# '한보고'

# %%
isTrue: bool =True
num1: float = 0.3
num2: int = 7
data1: str = "홍길동"

# %%
data2: list[int] = [10, 20, 30]
data3: list[str] = ["a","b","c"]

# %%
from typing import Any

data4: list = [10, "ㄱ", True]

# %%
user_info = {
    "name" : "홍길동",
    "age": 20,
    "address": "강남",
    "is_rich":
}

# %%
from typing import Predict
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from typing import Predict
#
# ImportError: cannot import name 'Predict' from 'typing' (C:\python311\Lib\typing.py)

# %% [markdown]
# ## pydantic
# - 파이썬에서 데이터를 검증하기 위한 라이브러리
# - 타입 힌트와 동일하나, 타입 불일치 시 오류

# %%
from pydantic import BaseModel

# %%
class User(BaseModel):
    name: str
    address: str
    hobby: str

# %%
user2_data = {
    "id": 10,
    "name": "장보고",
    "address": "경기도 구리시",
    "hobby": "코딩"
}

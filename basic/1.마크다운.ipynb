# %%
# Ctrl + Enter (셀 실행)

# %% [markdown]
# print("hello world")
#
# # 마크 다운(텍스트셀)
#
#     - 일반 텍스트 기반의 경량 마크업 언어로 웹 표준이 아닌 언어이다. 마크업이란, 태그 등을 이용하여 문서나 데이터의 구조 등을 기술하며, 텍스트만으로 서식이 있는 문서들을 작성할 때 자주 사용된다. 또한 다른 마크업 언어들에 비해 문법이 쉽고 간단하여 HTML 등의 서실 문서들로 쉽게 변환되기 때문에 README 파일이나 온라인 게시물 등에 자주 사용된다.

# %% [markdown]
# ## 목차(header)
# - h1
# - ### h2
# -  -S3개

# %% [markdown]
# ## 목차(header)
# - h1
# - ### h2
# -  -S3개

# %% [markdown]
# ## 리스트(list)
#
# 1. 장점
#         --  간편하게 쉽다
#        -- 다양한 플랫폼에서 지원한다.
# 2. 단점
#        -- 표준이 아님.
#        -- 표현 매체마다 다르게 보임
#        -- 모든 **HTML**을 대체하진 못 함.

# %% [markdown]
# 1. **내용**: 강조
# 2. *내용*: 기울이기
# 3. --취소선~~ : 취소선
# 4. 내 <br /> 용:  와우 거대한 것

# %% [markdown]
# - <sup> 내용 </sup>: 위 첨자
#     o(nlog<sup>2</sup>)
#
# - <sub>내용</sub>: 아랫첨자
# - 홍길동<sub>작사</sub>
#
# - []: 대괄호(브레이킷)
# - {}: 중괄호(컬리 브레이스)
# - (): 소괄호(패런서시스)

# %% [markdown]
# ## 링크
# - [텍스트](주소)
# - [파이썬 공식문서](http://localhost:8888/tree/basic)

# %% [markdown]
# ## 표
# |번호|이름|
# |----|----|
# |001|홍길동|
# |002|장보고|
# |003|이순신|

# %% [markdown]
# ## 이미지 태그
# <img width="100" src="![image.png](attachment:4703b46e-e2c6-4c52-be3f-36a1788959cc.png)![image.png](attachment:2e0b7f30-91a4-4585-b9c3-2027cb7fa039.png)"

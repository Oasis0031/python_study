# %%
from datetime import datetime

datetime.now()

def add_number(num1, num2):
    print(datetime.now())
    return num1 + num2

# %%
add_number(10, 20)
# Out:
# 2026-05-12 10:14:13.934448
# 30

# %%
def concat(*args):
    return "".join(map(lambda data: str(data), args))

# %%
concat(10, 20, 30)
# Out:
# '102030'

# %%
def log_time(original_function):
    def logging(*args):
        print(datetime.now())
        return original_function(*args)
    return logging

# %%
@log_time
add_number(10, 20)
# Out:
#   Cell In[9], line 2
#     add_number(10, 20)
#     ^
# SyntaxError: invalid syntax

# %%
@log_time
def add_number(num1, num2):
    print(datetime.now())
    return num1 + num2

# %%
add_number(10, 20)
# Out:
# 2026-05-12 10:20:48.985693
# 2026-05-12 10:20:48.986696
# 30

# %%
def divide(num1, num2):
    return int(num1) / int(num2)

# %%
divide(10, 0)
# Out:
# 0으로 나눌 수 없습니다.

# %%
def divide(num1, num2):
    try:
        return int(num1) / int(num2)
    except ZeroDivisionError as e:
        print("0으로 나눌 수 없습니다.")
    except ValueError as e:
        print("정수만 입력할 수 잇습니다.")
    except Exception as e:
        print("알 수 없는 오류가 발생했습니다.")

# %%
divide(10, "ㄱ")
# Out:
# 정수만 입력할 수 잇습니다.

# %%
def subtract(num1, num2):
    try:
        return num1 - num2
    except TypeError as e:
        print("문자는 뺄 수 없습니다.")

# %%
subtract("ㄱ", 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 subtract("ㄱ", 10)
#
# Cell In[19], line 2, in subtract(num1, num2)
#       1 def subtract(num1, num2):
# ----> 2     return num1 - num2
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
def safe_calc(original_function):
    def exception_wrapper(*args):
        try:
            return original_function(*args)
        except ZeroDivisionError as e:
            print("0으로 나눌 수 없습니다")
        except ValueError as e:
            print("정수만 입력할 수 있습니다.")
        except TypeError as e:
            print("정수만 계산할 수 있습니다.")
        except Exception as e:
            print("알 수 없는 오류가 발생했습니다.")
            
    return exception_wrapper

# %%
@safe_calc
def divide(num1, num2):
    return num1/ num2

# %%
@safe_calc
def subtract(num1, num2):
    return num1 - num2

# %%
# 이름과 정수를 몇 개 입력할 지 모를 때
# "홍길동님이 전달한 총 합: 000"으로 출력해주는 메서드 구현

# %%
def print_total(*args, **kwards):
    print(kwards["name"])
    print(snum(args))

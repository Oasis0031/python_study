# %%
name = "홍길동"

# %%
name
# Out:
# '홍길동'

# %%
name = "장보고"

# %%
#원시타입의 참조주소가 바뀜.
print(name)
# Out:
# 장보고

# %%
age = 20

# %%
#JS처럼 자동 형변환이 안 된다.
# None
# 오류 - 타입에러 (int+ string이 불가)
print(name + 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(name + 20)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#숫자로 시작하는 변수명 x
123name - "홍길동"

# %%
#특수 문자는 _만 허용된다.
!@name = '홍길동'

# %%
#카멜 표기법은 사용 불가
nAme = "홍길동"

# %%
# 공백문자 사용 X
na me = "나 메"
# Out:
#   Cell In[13], line 2
#     na me = "나 메"
#        ^
# SyntaxError: invalid syntax

# %%
#한글 변수명은 사용 x
이름 = "홍길동"

# %%
my_name = "홍길동"
